# %% [markdown]
# <a href="https://colab.research.google.com/github/chandra-prashanth/learn-git/blob/main/tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("klo")
# Out:
# klo

# %%
import numpy as np
np.zeros((4,2))
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
import tensorflow as tf
a = tf.constant([[1.0,2.0],[4.0,5.0]])
b = tf.constant([[4.0,1.0],[8.0,9.0]])
e = tf.matmul(a,b)
print(e)
# Out:
# tf.Tensor(
# [[20. 19.]
#  [56. 49.]], shape=(2, 2), dtype=float32)

# %%
??tf

# %%
import tensorflow_datasets as tfds
??tfds

# %%
tfds.list_builders()
# Out:
# ['abstract_reasoning',
#  'accentdb',
#  'aeslc',
#  'aflw2k3d',
#  'ag_news_subset',
#  'ai2_arc',
#  'ai2_arc_with_ir',
#  'ai2dcaption',
#  'aloha_mobile',
#  'amazon_us_reviews',
#  'anli',
#  'answer_equivalence',
#  'arc',
#  'asqa',
#  'asset',
#  'assin2',
#  'asu_table_top_converted_externally_to_rlds',
#  'austin_buds_dataset_converted_externally_to_rlds',
#  'austin_sailor_dataset_converted_externally_to_rlds',
#  'austin_sirius_dataset_converted_externally_to_rlds',
#  'bair_robot_pushing_small',
#  'bc_z',
#  'bccd',
#  'beans',
#  'bee_dataset',
#  'beir',
#  'berkeley_autolab_ur5',
#  'berkeley_cable_routing',
#  'berkeley_fanuc_manipulation',
#  'berkeley_gnm_cory_hall',
#  'berkeley_gnm_recon',
#  'berkeley_gnm_sac_son',
#  'berkeley_mvp_converted_externally_to_rlds',
#  'berkeley_rpt_converted_externally_to_rlds',
#  'big_patent',
#  'bigearthnet',
#  'billsum',
#  'binarized_mnist',
#  'binary_alpha_digits',
#  'ble_wind_field',
#  'blimp',
#  'booksum',
# ...

# %%
import matplotlib.pyplot as plt
??plt

# %%
x = [1,2,3,9]
y = tuple(x)
print(y)
# Out:
# (1, 2, 3, 9)

# %%
fig, axs = plt.subplots(2,1)

# %%
x = [55,56,78]
y = [46,90,110]
plt.plot(x,y,color="black",linestyle = '--',marker='o',label='Data')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Data sample")
plt.legend()

# %%
plt.savefig('plot.png',dpi=300,bbox_inches='tight')

# %%
import matplotlib.image as mpimg

# Load the image using matplotlib's imread function
img = mpimg.imread('plot.png')

# Display the image
plt.imshow(img)
plt.axis('on')  # Turn off axis
plt.show()

# %%
from PIL import Image

# Open the image from the file
image = Image.open('plot.png')

# Show the image (optional)
image.show()

# %%
z = [46,90,110]
plt.scatter(x,y,c=z,cmap='viridis')

# %%
x = [55,56,78]
y = [46,90,110]
plt.plot(x,y,color='black')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Data sample")
plt.show()

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [5, 4, 3, 2, 1]

# Dataset 2
x2 = [1, 2, 3, 4, 5]
y2 = [1, 2, 3, 4, 5]

# %%
plt.figure(figsize=(12, 4))  #figsize controls the physical dimensions (width and height) of the plot.

# Scatter plot for Dataset 1
plt.subplot(121)  #plt.subplot(121) creates the first subplot in a 1x2 grid and plots the first graph.
plt.scatter(x1, y1, label='Dataset 1')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Association in Dataset 1')
plt.legend()

# Scatter plot for Dataset 2
plt.subplot(122)   #plt.subplot(122) creates the second subplot in the same grid and plots the second graph.
plt.scatter(x2, y2, label='Dataset 2')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Association in Dataset 2')
plt.legend()

plt.tight_layout()
plt.show()

# %%
x = [i for i in range(0,10)]
y = [i for i in range(11,21)]
p = [i for i in range(90,120)]
q = [i for i in range(50,80)]

# %%
plt.figure(figsize=(20,8))

plt.subplot(121)
plt.scatter(x,y,label="Dataset 1")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title("Association in dataset1")
plt.legend()
plt.subplot(122)
plt.scatter(p,q,label="Dataset 2")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Assciation in dataset 2")
plt.legend()

plt.tight_layout()
plt.show()

# %%
physical_devices = tf.config.list_physical_devices('CPU')
print("Num CPUs:", len(physical_devices))
# Out:
# Num CPUs: 1

# %%
physical_devices = tf.config.list_physical_devices('GPU')
try:
  # Disable all GPUS
  tf.config.set_visible_devices([], 'GPU')
  visible_devices = tf.config.get_visible_devices()
  for device in visible_devices:
    assert device.device_type != 'GPU'
except:
  # Invalid device or cannot modify virtual devices once initialized.
  pass

# %%
import tensorflow_datasets as tfds
print(tfds.__version__)
# Out:
# 4.9.7

# %%
print(len(tfds.list_builders()))
# Out:
# 1296

# %%
print(tfds.list_builders()[:5])
# Out:
# ['abstract_reasoning', 'accentdb', 'aeslc', 'aflw2k3d', 'ag_news_subset']

# %%
celeba_bldr = tfds.builder('celeb_a')

# %%
print(celeba_bldr.info.features)
# Out:
# FeaturesDict({
#     'attributes': FeaturesDict({
#         '5_o_Clock_Shadow': bool,
#         'Arched_Eyebrows': bool,
#         'Attractive': bool,
#         'Bags_Under_Eyes': bool,
#         'Bald': bool,
#         'Bangs': bool,
#         'Big_Lips': bool,
#         'Big_Nose': bool,
#         'Black_Hair': bool,
#         'Blond_Hair': bool,
#         'Blurry': bool,
#         'Brown_Hair': bool,
#         'Bushy_Eyebrows': bool,
#         'Chubby': bool,
#         'Double_Chin': bool,
#         'Eyeglasses': bool,
#         'Goatee': bool,
#         'Gray_Hair': bool,
#         'Heavy_Makeup': bool,
#         'High_Cheekbones': bool,
#         'Male': bool,
#         'Mouth_Slightly_Open': bool,
#         'Mustache': bool,
#         'Narrow_Eyes': bool,
#         'No_Beard': bool,
#         'Oval_Face': bool,
#         'Pale_Skin': bool,
#         'Pointy_Nose': bool,
#         'Receding_Hairline': bool,
#         'Rosy_Cheeks': bool,
#         'Sideburns': bool,
# ...

# %%
celeba_bldr.download_and_prepare()
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ---------------------------------------------------------------------------
# NonMatchingChecksumError                  Traceback (most recent call last)
# <ipython-input-7-1847a08068cb> in <cell line: 1>()
# ----> 1 celeba_bldr.download_and_prepare()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config, file_format, permissions)
#     754           self.info.read_from_directory(self.data_dir)
#     755         else:
# --> 756           self._download_and_prepare(
# ...

# %%
datasets = celeba_bldr.as_dataset(shuffle_files=False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-a11cfffa40cd> in <cell line: 1>()
# ----> 1 datasets = celeba_bldr.as_dataset(shuffle_files=False)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/dataset_builder.py in as_dataset(self, split, batch_size, shuffle_files, decoders, read_config, as_supervised)
#    1002     # pylint: enable=line-too-long
#    1003     if not self.data_path.exists():
# -> 1004       raise AssertionError(
#    1005           "Dataset %s: could not find data in %s. Please make sure to call "
# ...

# %%
import tensorflow_datasets as tfds

# Build the dataset
builder = tfds.builder('celeb_a')
builder.download_and_prepare()

# Load the dataset
dataset = builder.as_dataset(split='train')
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ---------------------------------------------------------------------------
# NonMatchingChecksumError                  Traceback (most recent call last)
# <ipython-input-9-c39a9b7eb8b8> in <cell line: 5>()
#       3 # Build the dataset
#       4 builder = tfds.builder('celeb_a')
# ----> 5 builder.download_and_prepare()
#       6
#       7 # Load the dataset
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config, file_format, permissions)
# ...

# %%
import tensorflow_datasets as tfds

# Load the CelebA dataset
dataset, info = tfds.load('celeb_a', split='train', as_supervised=True, with_info=True, download=True)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ---------------------------------------------------------------------------
# NonMatchingChecksumError                  Traceback (most recent call last)
# <ipython-input-10-01b4f7007c36> in <cell line: 4>()
#       2
#       3 # Load the CelebA dataset
# ----> 4 dataset, info = tfds.load('celeb_a', split='train', as_supervised=True, with_info=True, download=True)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# ...

# %%
dataset, info = tfds.load('celeb_a', split='train', download=True, data_dir='/path/to/custom_directory')
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ---------------------------------------------------------------------------
# NonMatchingChecksumError                  Traceback (most recent call last)
# <ipython-input-11-de7175b6cd9d> in <cell line: 1>()
# ----> 1 dataset, info = tfds.load('celeb_a', split='train', download=True, data_dir='/path/to/custom_directory')
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
# ...

# %%
# !pip install --upgrade tensorflow-datasets

# %%
dataset, info = tfds.load(
    'celeb_a',
    split='train',
    data_dir='/content/tensorflow_datasets',
    as_supervised=True,
    with_info=True
)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ---------------------------------------------------------------------------
# NonMatchingChecksumError                  Traceback (most recent call last)
# <ipython-input-13-fec4485bbd94> in <cell line: 1>()
# ----> 1 dataset, info = tfds.load(
#       2     'celeb_a',
#       3     split='train',
#       4     data_dir='/content/tensorflow_datasets',
#       5     as_supervised=True,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# ...

# %%
# !rm -rf /content/tensorflow_datasets/downloads/celeb_a

# %%
import tensorflow_datasets as tfds

dataset, info = tfds.load(
    'celeb_a',
    split='train',
    data_dir='/content/tensorflow_datasets',
    as_supervised=True,
    with_info=True,
    download=True #Explicitly set download to True to force redownload
)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ---------------------------------------------------------------------------
# NonMatchingChecksumError                  Traceback (most recent call last)
# <ipython-input-15-032ad4129cbb> in <cell line: 3>()
#       1 import tensorflow_datasets as tfds
#       2
# ----> 3 dataset, info = tfds.load(
#       4     'celeb_a',
#       5     split='train',
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# ...

# %%
import tensorflow as tf
ds = tfds.load('mnist', split='train', shuffle_files=True)
assert isinstance(ds, tf.data.Dataset)
print(ds)
# Out:
# <_PrefetchDataset element_spec={'image': TensorSpec(shape=(28, 28, 1), dtype=tf.uint8, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None)}>

# %%
ds = tfds.load('mnist', split='train')
ds = ds.take(1)  # Only take a single example

for example in ds:  # example is `{'image': tf.Tensor, 'label': tf.Tensor}`
  print(list(example.keys()))
  image = example["image"]
  label = example["label"]
  print(image.shape, label)
# Out:
# ['image', 'label']
# (28, 28, 1) tf.Tensor(4, shape=(), dtype=int64)

# %%
ds = tfds.load('mnist', split='train', as_supervised=True)
ds = ds.take(1)

for image, label in tfds.as_numpy(ds):
  print(type(image), type(label), label)
# Out:
# <class 'numpy.ndarray'> <class 'numpy.int64'> 4

# %%
# Import `importlib` to reload the module
import importlib
import tensorflow_datasets as tfds

# Reload the `celeb_a` module within `tensorflow_datasets`
importlib.reload(tfds.datasets.celeb_a)

# Now try to load the dataset
dataset, info = tfds.load(
    'celeb_a',
    split='train',
    data_dir='/content/tensorflow_datasets',
    as_supervised=True,
    with_info=True,
    download=True
)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ---------------------------------------------------------------------------
# NonMatchingChecksumError                  Traceback (most recent call last)
# <ipython-input-20-071ba89dd0e4> in <cell line: 9>()
#       7
#       8 # Now try to load the dataset
# ----> 9 dataset, info = tfds.load(
#      10     'celeb_a',
#      11     split='train',
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# ...

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 11 18:13:04 2016
Benchmarking on the boston housing dataset
@author: Rupak Chakraborty
"""

import pandas as pd
import numpy as np
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ElasticNet
from sklearn import metrics
from sklearn.model_selection import train_test_split


import random

datafile = "Boston Housing/housing.data"
dataFrame = pd.read_csv(')
dataArray = np.zeros((len(dataFrame),13))
dataOutput = np.zeros((len(dataFrame),1))

column_names = ["CRIM","ZN","INDUS","CHAS","NOX","RM","AGE","DIS","RAD","TAX","PTRATIO","B" \
,"LSTAT","MEDV"]

for i in range(len(dataFrame)):

    feature_string = dataFrame.iloc[i][0]
    feature_list = feature_string.split()

    for j in range(len(feature_list)):

        if j != len(feature_list)-1:
            dataArray[i][j] = float(feature_list[j])
        else:
            dataOutput[i] = float(feature_list[j])

random.shuffle(dataArray)

ada = AdaBoostRegressor()
rf = RandomForestRegressor()
bagging = BaggingRegressor()
grad = GradientBoostingRegressor()
svr = SVR()
bayes_ridge = BayesianRidge()
elastic_net = ElasticNet()

regressors = [ada,rf,bagging,grad,svr,bayes_ridge,elastic_net]
regressor_names = ["AdaBoost","Random Forest","Bagging","Gradient Boost","SVR","Bayesian Ridge","Elastic Net"]

train_data,test_data,train_values,test_values = train_test_split(dataArray,dataOutput,test_size=0.3)

for regressor,regressor_name in zip(regressors,regressor_names):

    regressor.fit(train_data,train_values)
    predicted_values = list(regressor.predict(test_data))

    print("-----------------------------------\n")
    print("For Regressor : ",regressor_name)
    print("Mean Absolute Error : ",metrics.mean_absolute_error(list(test_values),predicted_values))
    print("Median Absolute Error : ",metrics.median_absolute_error(list(test_values),predicted_values))
    print("Mean Squared Error : ",metrics.mean_squared_error(list(test_values),predicted_values))
    print("R2 Score : ",metrics.r2_score(list(test_values),predicted_values))
    print("---------------------------------\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-0bfa90f62916> in <cell line: 24>()
#      22
#      23 datafile = "Boston Housing/housing.data"
# ---> 24 dataFrame = pd.read_csv(datafile,header=None,sep='\t')
#      25 dataArray = np.zeros((len(dataFrame),13))
#      26 dataOutput = np.zeros((len(dataFrame),1))
#
# ...

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np

from IPython.display import Image

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
celeba_bldr = tfds.builder('celeb_a')
celeba_bldr.download_and_prepare()
celeba = celeba_bldr.as_dataset(shuffle_files=False)
print(celeba.keys())

celeba_train = celeba['train']
celeba_valid = celeba['validation']
celeba_test = celeba['test']

def count_items(ds):
    n = 0
    for _ in ds:
        n += 1
    return n

print('Train set:  {}'.format(count_items(celeba_train)))
print('Validation: {}'.format(count_items(celeba_valid)))
print('Test set:   {}'.format(count_items(celeba_test)))
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ---------------------------------------------------------------------------
# NonMatchingChecksumError                  Traceback (most recent call last)
# <ipython-input-2-770fb9ab511f> in <cell line: 0>()
#       1 celeba_bldr = tfds.builder('celeb_a')
# ----> 2 celeba_bldr.download_and_prepare()
#       3 celeba = celeba_bldr.as_dataset(shuffle_files=False)
#       4 print(celeba.keys())
#       5
#
# /usr/local/lib/python3.11/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config, file_format, permissions)
# ...

# %%
import tensorflow_datasets as tfds
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mnist_bldr = tfds.builder('mnist')
mnist_bldr.download_and_prepare()
datasets = mnist_bldr.as_dataset(shuffle_files=False)
print(datasets.keys())
mnist_train_orig, mnist_test_orig = datasets['train'], datasets['test']
# Out:
# ...
# Dl Completed...:   0%|          | 0/5 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# dict_keys(['test', 'train'])
