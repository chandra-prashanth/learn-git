# %% [markdown]
# <a href="https://colab.research.google.com/github/chandra-prashanth/learn-git/blob/main/time_series_forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import tensorflow_datasets as tfds

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git clone https://github.com/chandra-prashanth/googlecolab.git
# Out:
# Cloning into 'googlecolab'...
# ...

# %%
# !pwd
# Out:
# /content

# %%
import pandas as pd
from google.colab import files

# Upload the CSV file from your local machine
uploaded = files.upload()

# Assuming the file is named 'jena_climate_2009_2016.csv'
csv_filename = 'jena_climate_2009_2016.csv'

# Load the CSV into a DataFrame
df = pd.read_csv(csv_filename)

# Display the first few rows
df.head()
# Out:
#      <input type="file" id="files-80c4d782-08a6-494f-b896-d3850b9d27ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80c4d782-08a6-494f-b896-d3850b9d27ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(csv_filename)

# Display the first few rows
df.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1  01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2  01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3  01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4  01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.11          0.22       1.94             3.12
# 1          3.23          3.02          0.21       1.89             3.03
# 2          3.21          3.01          0.20       1.88             3.02
# 3          3.26          3.07          0.19       1.92             3.08
# 4          3.27          3.08          0.19       1.92             3.09
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# ...

# %%
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df.columns
# Out:
# Index(['Date Time', 'p (mbar)', 'T (degC)', 'Tpot (K)', 'Tdew (degC)',
#        'rh (%)', 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'sh (g/kg)',
#        'H2OC (mmol/mol)', 'rho (g/m**3)', 'wv (m/s)', 'max. wv (m/s)',
#        'wd (deg)'],
#       dtype='object')

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 00:10:00  01.01.2009 00:10:00    996.52     -8.02    265.40
# 2009-01-01 00:20:00  01.01.2009 00:20:00    996.57     -8.41    265.01
# 2009-01-01 00:30:00  01.01.2009 00:30:00    996.53     -8.51    264.91
# 2009-01-01 00:40:00  01.01.2009 00:40:00    996.51     -8.31    265.12
# 2009-01-01 00:50:00  01.01.2009 00:50:00    996.51     -8.27    265.15
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 01:10:00  01.01.2009 01:10:00    996.50     -7.62    265.81
# 2009-01-01 01:20:00  01.01.2009 01:20:00    996.50     -7.62    265.81
# 2009-01-01 01:30:00  01.01.2009 01:30:00    996.50     -7.91    265.52
# 2009-01-01 01:40:00  01.01.2009 01:40:00    996.53     -8.43    264.99
# 2009-01-01 01:50:00  01.01.2009 01:50:00    996.62     -8.76    264.66
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# ...

# %%
df = df[5::6]
df
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# ...                                  ...       ...       ...       ...
# 2016-12-31 19:10:00  31.12.2016 19:10:00   1002.18     -0.98    272.01
# 2016-12-31 20:10:00  31.12.2016 20:10:00   1001.40     -1.40    271.66
# 2016-12-31 21:10:00  31.12.2016 21:10:00   1001.19     -2.75    270.32
# 2016-12-31 22:10:00  31.12.2016 22:10:00   1000.65     -2.89    270.22
# 2016-12-31 23:10:00  31.12.2016 23:10:00   1000.11     -3.93    269.23
#
#                      Tdew (degC)  rh (%)  VPmax (mbar)  VPact (mbar)  \
# Date Time
# ...

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <Axes: xlabel='Date Time'>

# %%
def df_to_x_y(df, window_size=5):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row =[[a] for a in df_as_np[i:i+5]]
        X.append(row)
        label = df_as_np[i+5]
        y.append(label)
    return np.array(X), np.array(y)

# %%
window_size = 5
X, y = df_to_x_y(temp, window_size)
X.shape, y.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
x_train, y_train = X[:60000], y[:60000]
x_test, y_test = X[65000:], y[65000:]
x_val,y_val = X[60000:65000], y[60000:65000]
x_train.shape, y_train.shape,x_val.shape,y_val.shape,x_test.shape,y_test.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# Define the model
model = Sequential()

# Add layers
model.add(InputLayer((5, 1)))  # Input shape: 5 timesteps, 1 feature
model.add(LSTM(64))            # LSTM layer with 64 units
model.add(Dense(8, 'relu'))    # Dense layer with 8 units and ReLU activation
model.add(Dense(1, 'linear'))  # Output layer with 1 unit and linear activation

# Print model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp = ModelCheckpoint('model/best_model.keras',save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=10, callbacks=[cp])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 54.0064 - root_mean_squared_error: 7.0448 - val_loss: 1.3113 - val_root_mean_squared_error: 1.1451
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 2.5017 - root_mean_squared_error: 1.5785 - val_loss: 0.6771 - val_root_mean_squared_error: 0.8229
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 1.0903 - root_mean_squared_error: 1.0431 - val_loss: 0.5432 - val_root_mean_squared_error: 0.7370
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.7698 - root_mean_squared_error: 0.8772 - val_loss: 0.5134 - val_root_mean_squared_error: 0.7165
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.7031 - root_mean_squared_error: 0.8384 - val_loss: 0.5211 - val_root_mean_squared_error: 0.7219
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.6758 - root_mean_squared_error: 0.8220 - val_loss: 0.4935 - val_root_mean_squared_error: 0.7025
# ...

# %%
from tensorflow.keras.models import load_model
model = load_model('model/best_model.keras')

# %%
train_pred = model.predict(x_train).flatten()
train_res = pd.DataFrame(data={'Prediction': train_pred,'Actuals':y_train})
train_res
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
#        Prediction  Actuals
# 0       -9.454265    -9.67
# 1       -9.349207    -9.17
# 2       -8.596627    -8.10
# 3       -7.206281    -7.66
# 4       -6.953957    -7.04
# ...           ...      ...
# 59995    6.346472     6.07
# 59996    7.297565     9.88
# 59997   12.198482    13.53
# 59998   16.348209    15.43
# 59999   16.679823    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_res['Prediction'][50:100], label='Prediction')
plt.plot(train_res['Actuals'][50:100], label='Actuals')
plt.legend()
plt.show()

# %%
val_pred = model.predict(x_val).flatten()
val_res = pd.DataFrame(data={'Prediction': val_pred,'Actuals':y_val})
val_res
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#       Prediction  Actuals
# 0      15.341785    14.02
# 1      13.073634    13.67
# 2      13.038816    12.27
# 3      11.523056    11.19
# 4      10.412118    10.85
# ...          ...      ...
# 4995   17.190910    18.27
# 4996   17.396051    17.85
# 4997   17.111769    16.65
# 4998   15.795511    15.85
# 4999   15.036313    15.09
#
# [5000 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Prediction'].plot(kind='hist', bins=20, title='Prediction')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Actuals'].plot(kind='hist', bins=20, title='Actuals')
# ...
